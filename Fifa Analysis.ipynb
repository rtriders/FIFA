# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objs as go 
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
#Total No Of Left VS Right Foot Players

# %%
L = df['Preferred Foot'].value_counts()
L = L.reset_index()
L.columns = ['Preferred Foot','Count']
L
# Out:
#   Preferred Foot  Count
# 0          Right  13948
# 1           Left   4211

# %%
sns.set_style('whitegrid')
sns.barplot(x='Preferred Foot',y='Count',data=L)
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='Count'>

# %%
#Does Preffered foot is having Some Effect On Overall Rating ?

# %%
df.groupby('Preferred Foot')['Overall'].mean()
# Out:
# Preferred Foot
# Left     66.801472
# Right    66.083381
# Name: Overall, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='Preferred Foot',y='Overall',data=df)
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='Overall'>

# %%
#Does Preffered foot is having Some Effect On Wage ?

# %%
df.groupby('Preferred Foot')['Wage'].mean()
# Out:
# Preferred Foot
# Left     10348.373308
# Right     9572.698595
# Name: Wage, dtype: float64

# %%
sns.barplot(x='Preferred Foot',y='Wage',data=df)
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='Wage'>

# %%
#Wage Analysis

# %%
#Age Vs Wage

# %%
plt.figure(figsize=(12,5))
sns.lmplot(x="Age", y="Wage",data=df,markers="*",
           order=2, ci=None, scatter_kws={"color": "green"},
         line_kws={"linewidth":3,"color":"red"},aspect=2);
plt.title(" Age vs Wage");

# %%
#Overall VS Wage

# %%
plt.figure(figsize=(12,5))
sns.lmplot(x="Overall", y="Wage",data=df,markers="*",
           order=2, ci=None, scatter_kws={"color": "red"},
         line_kws={"linewidth":3,"color":"green"},aspect=2);
plt.title(" Age vs Wage")
# Out:
# Text(0.5, 1.0, ' Age vs Wage')

# %%
#Finishing vs Wage

# %%
plt.figure(figsize=(12,5))
sns.lmplot(x="Finishing", y="Wage",data=df,markers="o",
           order=2, ci=None, scatter_kws={"color": "orange"},
         line_kws={"linewidth":3,"color":"green"},aspect=2);
plt.title(" Finishing vs Wage")
# Out:
# Text(0.5, 1.0, ' Finishing vs Wage')

# %%
#Height Analysis

# %%
df['Height'].value_counts()
# Out:
# 6'0     2881
# 5'10    2479
# 5'9     2238
# 5'11    2159
# 6'2     2015
# 6'1     1908
# 6'3      990
# 5'8      946
# 5'7      905
# 6'4      749
# 5'6      316
# 6'5      246
# 5'5      145
# 6'6       93
# 5'4       30
# 6'7       21
# 5'3       18
# 6'8       10
# 5'2        5
# 5'1        3
# 6'9        2
# Name: Height, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.set_context(font_scale=0.025)
sns.barplot(x="Height",y="Wage",data=df)
plt.title("Height vs Wage")
plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
sns.set_context(font_scale=0.025)
sns.boxplot(x="Height",y="Overall",data=df)
plt.title("Height vs Wage")
plt.tight_layout()

# %%
#Weight Analysis

# %%
df['Weight'].value_counts().head()
# Out:
# 165.0    1483
# 154.0    1439
# 176.0    1041
# 172.0     987
# 159.0     946
# Name: Weight, dtype: int64

# %%
df['Weight'] = df['Weight'].str.replace("lbs","").astype("float")

# %%
sns.lmplot(x="Weight", y="Wage",data=df,markers="*",
           order=2, ci=None, scatter_kws={"color": "cyan"},
         line_kws={"linewidth":3,"color":"red"},aspect=2);
plt.title("Figure : \n\n\n Weight vs Wage");

# %%
plt.figure(figsize=(15,4))
sns.set_context(font_scale=0.025)
sns.boxplot(y="Weight",x="Overall",data=df)
plt.title("Weight vs Wage")
plt.tight_layout()

# %%
B = df[['Nationality','Weight']]
B.groupby('Nationality').mean().sort_values(by='Weight',ascending=False)
# Out:
#                           Weight
# Nationality
# Oman                  205.000000
# Mauritius             194.000000
# Grenada               194.000000
# New Caledonia         192.000000
# Latvia                191.833333
# ...                          ...
# Thailand              142.800000
# Indonesia             141.000000
# Botswana              139.000000
# Ethiopia              137.000000
# United Arab Emirates  132.000000
#
# [164 rows x 1 columns]

# %%
#Countries With Large Mean Weight

# %%
sns.barplot(y='Nationality',x='Weight',data=B[:20])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Nationality'>

# %%
#Average Overall Rating Per Country

# %%
C = df[['Nationality','Overall']]
C.groupby('Nationality').mean().sort_values(by='Overall', ascending=False)[:10]
C.reset_index()
C[:10]
# Out:
#   Nationality  Overall
# 0   Argentina       94
# 1    Portugal       94
# 2      Brazil       92
# 3       Spain       91
# 4     Belgium       91
# 5     Belgium       91
# 6     Croatia       91
# 7     Uruguay       91
# 8       Spain       91
# 9    Slovenia       90

# %%
sns.boxplot(y='Nationality',x='Overall',data=C[:20])
# Out:
# <AxesSubplot:xlabel='Overall', ylabel='Nationality'>

# %%
#Players Whose Wage Are In Range 100-500k

# %%
def change_form_of_value(Value):
    change = Value.replace("€", "")
    if "M" in change:
        change = float(change.replace("M",""))*1000000
    elif "K" in change:
        change = float(change.replace("K", "")) * 1000
    return float(change)
df["Value"] = df["Value"].apply(lambda x: change_form_of_value(x))
df["Wage"] = df["Wage"].apply(lambda x: change_form_of_value(x))

# %%
p = df[(df['Wage']>=100000) & (df['Wage']<=500000)]['Wage'].count()
print('Total Count Of players with Wage range 100-500k is ',p)
# Out:
# Total Count Of players with Wage range 100-500k is  187

# %%
#Distribution of players at different positions

# %%
B = df['Position'].value_counts()
B = B.reset_index()
B.columns = ['Position','Count']
B.head()
# Out:
#   Position  Count
# 0       ST   2152
# 1       GK   2025
# 2       CB   1778
# 3       CM   1394
# 4       LB   1322

# %%
sns.set_context('poster',font_scale=0.5)
plt.figure(figsize=(15,5))
sns.barplot(x='Position',y='Count',data=B)
plt.tight_layout()
plt.title('Postion Wise Count')
# Out:
# Text(0.5, 1.0, 'Postion Wise Count')

# %%
#Best Players In Overall Rating Per Position

# %%
M = df[['Name','Position','Overall','Potential','Club','Nationality','Release Clause']].groupby('Overall')
M.head()
# Out:
#                     Name Position  Overall  Potential                 Club  \
# 0               L. Messi       RF       94         94         FC Barcelona
# 1      Cristiano Ronaldo       ST       94         94             Juventus
# 2              Neymar Jr       LW       92         93  Paris Saint-Germain
# 3                 De Gea       GK       91         93    Manchester United
# 4           K. De Bruyne      RCM       91         92      Manchester City
# ...                  ...      ...      ...        ...                  ...
# 18187          C. Ehlich       RB       47         59   SpVgg Unterhaching
# 18188         L. Collins       CM       47         62       Newport County
# 18189         A. Kaltner       ST       47         61   SpVgg Unterhaching
# 18190         L. Watkins       CM       47         67     Cambridge United
# 18206          G. Nugent       CM       46         66      Tranmere Rovers
#
#       Nationality Release Clause
# 0       Argentina        €226.5M
# ...

# %%
#Player Whose Contract Ends in 2019

# %%
df[df['Contract Valid Until']=='2019'][['ID','Name','Contract Valid Until','Age','Overall','Release Clause']]
# Out:
#            ID            Name Contract Valid Until  Age  Overall  \
# 12     182493        D. Godín                 2019   32       90
# 41       1179       G. Buffon                 2019   40       88
# 51     172871   J. Vertonghen                 2019   31       87
# 86     193747            Koke                 2019   26       85
# 94     184267      Y. Brahimi                 2019   28       85
# ...       ...             ...                  ...  ...      ...
# 18186  240917    Zhang Yufeng                 2019   20       47
# 18200  231381        J. Young                 2019   18       47
# 18202  238813    J. Lundstram                 2019   19       47
# 18205  246268  D. Walker-Rice                 2019   17       47
# 18206  246269       G. Nugent                 2019   16       46
#
#       Release Clause
# 12            €90.2M
# 41             €7.4M
# 51            €62.9M
# 86            €95.6M
# 94              €78M
# ...              ...
# 18186          €167K
# ...

# %%
#Age Distribution Of Players

# %%
sns.set_context('poster',font_scale=0.5)
plt.figure(figsize=(15,5))
sns.distplot(x=df['Age'],color='purple')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#Top 10 Players According To Value

# %%
df[['Name','Value','Club','Skill Moves']].sort_values(by='Value',ascending=False)[:10]
# Out:
#               Name        Value                 Club  Skill Moves
# 2        Neymar Jr  118500000.0  Paris Saint-Germain          5.0
# 0         L. Messi  110500000.0         FC Barcelona          4.0
# 4     K. De Bruyne  102000000.0      Manchester City          4.0
# 5        E. Hazard   93000000.0              Chelsea          4.0
# 15       P. Dybala   89000000.0             Juventus          4.0
# 16         H. Kane   83500000.0    Tottenham Hotspur          3.0
# 25       K. Mbappé   81000000.0  Paris Saint-Germain          5.0
# 7        L. Suárez   80000000.0         FC Barcelona          3.0
# 17    A. Griezmann   78000000.0      Atlético Madrid          4.0
# 10  R. Lewandowski   77000000.0    FC Bayern München          4.0

# %%
#Potential And Overall

# %%
A = df[['Name','Nationality','Overall','Club']].sort_values(by='Overall' ,ascending=False)[:11]
sns.set_context('poster',font_scale=0.5)
plt.figure(figsize=(10,3))
sns.barplot(x=A['Name'],y=A['Overall'],data=A,color='brown')
plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
G = df[['Name','Potential']].sort_values(by='Potential' ,ascending=False)[:10]
sns.barplot(x='Potential',y='Name',data=G,color='yellow')
# Out:
# <AxesSubplot:xlabel='Potential', ylabel='Name'>

# %%
#Top Wage Clubs

# %%
sns.barplot(y='Club',x='Wage',data=df[:10])
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Club'>

# %%
#Display the distribution of the players nationalities on a histogram

# %%
A = df['Nationality'].value_counts()
A = A.reset_index()
A.columns = ['Nation','Count']
sns.set_style('whitegrid')
sns.set_context('poster',font_scale=0.8)
plt.figure(figsize=(20,50))
sns.barplot(y='Nation',x='Count',data=A)
plt.tight_layout()
plt.title('Nation Wise Player Count')
# Out:
# Text(0.5, 1.0, 'Nation Wise Player Count')
